# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import osmanage as om
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
foldername = 'plot_dump/'
filename = 'log.lammps' 
f = open(filename)
data = []
lines = f.read().strip().split('\n')
lines[-1] = lines[-1] + ' '
idy = 0
while idy < len(lines):
    if lines[idy][0:4]=='Step':
        header = lines[idy].split()[:]
        break
    idy += 1

idx = 0
idx += 1
while idx < len(lines): 
    while idx < len(lines):
        if lines[idx][0:4]=='Step':
            break
        idx += 1
    idx += 1
    while idx < len(lines):
        if lines[idx][0:4]=='Loop':
            break
        data.append( lines[idx][:].split() )
        idx += 1
    idx += 1

datapd = pd.DataFrame(data=data, columns=header).astype('float64')

# %%
# thermo hdf5
# import 
import re
import time
from itertools import chain
from itertools import repeat
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D
# import project module
import data_arrange as da
import datapath as dp
import output_control as oc
# ======================================

# create folder
om.create_directory(dp.post_process_path)
om.create_directory(dp.hdf5_csv_path)
da.file_to_h5_csv(f_thermo, f_output_name, override ='no')

# %%
#normalize factor
rp = 0.000415
d = 2500
mass = np.pi*4/3*rp**3*d

# %%
datapd
# Out:
#             Step     Atoms        KinEng         c_KEr        v_KEtr  \
# 0      2000000.0  132824.0  5.307971e-17  9.434490e-17  1.474246e-16
# 1      2000001.0  132824.0  5.307868e-17  9.434512e-17  1.474238e-16
# 2      2000002.0  132824.0  5.307766e-17  9.434531e-17  1.474230e-16
# 3      2000003.0  132824.0  5.307666e-17  9.434547e-17  1.474221e-16
# 4      2000004.0  132824.0  5.307568e-17  9.434558e-17  1.474213e-16
# 5      2000005.0  132824.0  5.307472e-17  9.434566e-17  1.474204e-16
# 6      2000006.0  132824.0  5.307378e-17  9.434570e-17  1.474195e-16
# 7      2000007.0  132824.0  5.307287e-17  9.434571e-17  1.474186e-16
# 8      2000008.0  132824.0  5.307200e-17  9.434567e-17  1.474177e-16
# 9      2000009.0  132824.0  5.307115e-17  9.434560e-17  1.474168e-16
# 10     2000010.0  132824.0  5.307035e-17  9.434550e-17  1.474158e-16
# 11     2000011.0  132824.0  5.306958e-17  9.434535e-17  1.474149e-16
# 12     2000012.0  132824.0  5.306885e-17  9.434517e-17  1.474140e-16
# 13     2000013.0  132824.0  5.306817e-17  9.434495e-17  1.474131e-16
# 14     2000014.0  132824.0  5.306753e-17  9.434470e-17  1.474122e-16
# 15     2000015.0  132824.0  5.306693e-17  9.434441e-17  1.474113e-16
# 16     2000016.0  132824.0  5.306638e-17  9.434409e-17  1.474105e-16
# 17     2000017.0  132824.0  5.306588e-17  9.434374e-17  1.474096e-16
# 9994   2009994.0  132824.0  5.309589e-17  9.433929e-17  1.474352e-16
# 9995   2009995.0  132824.0  5.309578e-17  9.433922e-17  1.474350e-16
# 9996   2009996.0  132824.0  5.309561e-17  9.433923e-17  1.474349e-16
# 9997   2009997.0  132824.0  5.309539e-17  9.433931e-17  1.474347e-16
# 9998   2009998.0  132824.0  5.309510e-17  9.433945e-17  1.474346e-16
# 9999   2009999.0  132824.0  5.309475e-17  9.433965e-17  1.474344e-16
# 10000  2010000.0  132824.0  5.309435e-17  9.433990e-17  1.474343e-16
#
#           v_EKP  c_trace_id_reduce[2]
# 0      0.012424                6773.0
# 1      0.012424                6773.0
# 2      0.012424                6773.0
# 3      0.012424                6773.0
# 4      0.012424                6773.0
# 5      0.012424                6773.0
# 6      0.012424                6773.0
# 7      0.012424                6773.0
# 8      0.012424                6773.0
# 9      0.012424                6773.0
# 10     0.012424                6773.0
# 11     0.012424                6773.0
# 12     0.012424                6773.0
# 13     0.012424                6773.0
# 14     0.012424                6773.0
# 15     0.012424                6773.0
# 16     0.012424                6773.0
# 17     0.012424                6773.0
# 18     0.012424                6773.0
# 19     0.012424                6773.0
# 20     0.012424                6773.0
# 21     0.012424                6773.0
# 22     0.012424                6773.0
# 23     0.012424                6773.0
# 24     0.012424                6773.0
# 25     0.012424                6773.0
# 26     0.012424                6773.0
# 27     0.012424                6773.0
# 28     0.012424                6773.0
# 29     0.012424                6773.0
# ...         ...                   ...
# 9971   0.012424                6773.0
# 9972   0.012424                6773.0
# 9973   0.012424                6773.0
# 9974   0.012424                6773.0
# 9975   0.012424                6773.0
# 9976   0.012424                6773.0
# 9977   0.012424                6773.0
# 9978   0.012424                6773.0
# 9979   0.012424                6773.0
# 9980   0.012424                6773.0
# 9981   0.012424                6773.0
# 9982   0.012424                6773.0
# 9983   0.012424                6773.0
# 9984   0.012424                6773.0
# 9985   0.012424                6773.0
# 9986   0.012424                6773.0
# 9987   0.012424                6773.0
# 9988   0.012424                6773.0
# 9989   0.012424                6773.0
# 9990   0.012424                6773.0
# 9991   0.012424                6773.0
# 9992   0.012424                6773.0
# 9993   0.012424                6773.0
# 9994   0.012424                6773.0
# 9995   0.012424                6773.0
# 9996   0.012424                6773.0
# 9997   0.012424                6773.0
# 9998   0.012424                6773.0
# 9999   0.012424                6773.0
# 10000  0.012424                6773.0
#
# [10001 rows x 7 columns]

# %%
scale_x = 'linear'
scale_y = 'linear'

x_variable_name = 'Step'
y_variable_name = 'c_max[4]'  #c_ke_rotate  v_check_value  PotEng   c_max[4]/c_max[2]

timestep_start = 1
timestep_end = -1

x = datapd[x_variable_name][timestep_start: timestep_end]
y = datapd[y_variable_name][timestep_start: timestep_end]

x = x.values.astype('float64')
y = y.values.astype('float64')/rp

fig = plt.figure()
plt.plot(x,y,'.')
plt.xscale(scale_x)
plt.yscale(scale_y)
plt.xticks(rotation=20)
plt.xlabel(x_variable_name)
plt.ylabel('KE_max')
fig.savefig(foldername + filename + '_maxKE' + '_scale' +scale_x + scale_y + '.png',bbox_inches='tight')   # save the figure to file

# %%
scale_x = 'linear'
scale_y = 'linear'

x_variable_name = 'Step'
y_variable_name = 'c_max[2]'  #c_ke_rotate  v_check_value  PotEng   c_max[4]/c_max[2]

timestep_start = 1
timestep_end = -1

x = datapd[x_variable_name][timestep_start: timestep_end]
y = datapd[y_variable_name][timestep_start: timestep_end]

x = x.values.astype('float64')
y = y.values.astype('float64')/mass/rp**2

fig = plt.figure()
plt.plot(x,y,'.')
plt.xscale(scale_x)
plt.yscale(scale_y)
plt.xticks(rotation=20)
plt.xlabel(x_variable_name)
plt.ylabel('KE_max')
fig.savefig(foldername + filename + '_maxKE' + '_scale' +scale_x + scale_y + '.png',bbox_inches='tight')   # save the figure to file

# %%
scale_x = 'linear'
scale_y = 'linear'

x_variable_name = 'Step'
y_variable_name = 'v_KEtr'  #c_ke_rotate  v_check_value  PotEng   c_max[4]/c_max[2]

timestep_start = 1
timestep_end = 10000

x = datapd[x_variable_name][timestep_start: timestep_end]
y = datapd[y_variable_name][timestep_start: timestep_end]

x = x.values.astype('float64')
y = y.values.astype('float64')/mass/rp**2

fig = plt.figure()
plt.xscale(scale_x)
plt.yscale(scale_y)
plt.xticks(rotation=20)
plt.xlabel(x_variable_name)
plt.ylabel('KE')
plt.plot(x,y,'.')
fig.savefig(foldername + filename + '_KE' + '_scale' +scale_x + scale_y + '.png',bbox_inches='tight')   # save the figure to file

# %%
scale_x = 'linear'
scale_y = 'log'

x_variable_name = 'Step'
y1_variable_name = 'v_check_value'
y3_variable_name = 'Atoms'

timestep_start = 1
timestep_end = -1

x = datapd[x_variable_name][timestep_start: timestep_end]
y1 = datapd[y1_variable_name][timestep_start: timestep_end]
y3 = datapd[y3_variable_name][timestep_start: timestep_end]

x = x.values.astype('float64')
y1 = y1.values.astype('float64')
y3 = y3.values.astype('float64')

y = y1/y3
y = y/mass/rp**2

fig = plt.figure()
plt.xscale(scale_x)
plt.yscale(scale_y)
plt.xticks(rotation=20)
plt.xlabel(x_variable_name)
plt.ylabel('aveKE')
plt.plot(x,y,'.')
fig.savefig(foldername + filename + '_aveKE' + '.png',bbox_inches='tight')   # save the figure to file

# %%
scale_x = 'linear'
scale_y = 'linear'

x_variable_name = 'Step'
y1_variable_name = 'v_check_value'
y2_variable_name = 'PotEng'
y3_variable_name = 'Atoms'

timestep_start = 1
timestep_end = -1

x = datapd[x_variable_name][timestep_start: timestep_end]
y1 = datapd[y1_variable_name][timestep_start: timestep_end]
y2 = datapd[y2_variable_name][timestep_start: timestep_end]
y3 = datapd[y3_variable_name][timestep_start: timestep_end]

x = x.values.astype('float64')
y1 = y1.values.astype('float64')
y2 = y2.values.astype('float64')
y3 = y3.values.astype('float64')

y = y1/y3+y2
y = y/mass/rp**2

fig = plt.figure()
plt.xscale(scale_x)
plt.yscale(scale_y)
plt.xticks(rotation=20)
plt.xlabel(x_variable_name)
plt.ylabel('aveKE+avePEg')
plt.plot(x,y,'.')
fig.savefig(foldername + filename + '_aveKE+avePEg' + '.png',bbox_inches='tight')   # save the figure to file
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PotEng'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-248-5742f5bd3094> in <module>()
#      12 x = datapd[x_variable_name][timestep_start: timestep_end]
#      13 y1 = datapd[y1_variable_name][timestep_start: timestep_end]
# ---> 14 y2 = datapd[y2_variable_name][timestep_start: timestep_end]
#      15 y3 = datapd[y3_variable_name][timestep_start: timestep_end]
#      16
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PotEng'

# %%
scale_x = 'linear'
scale_y = 'linear'

x_variable_name = 'Step'
y1_variable_name = 'c_max[4]'
y2_variable_name = 'c_max[2]'

timestep_start = 1
timestep_end = -1

x = datapd[x_variable_name][timestep_start: timestep_end]
y1 = datapd[y1_variable_name][timestep_start: timestep_end]
y2 = datapd[y2_variable_name][timestep_start: timestep_end]

x = x.values.astype('float64')
y1 = y1.values.astype('float64')
y2 = y2.values.astype('float64')

y = y1/y2

fig = plt.figure()
plt.xscale(scale_x)
plt.yscale(scale_y)
plt.xticks(rotation=20)
plt.xlabel(x_variable_name)
plt.ylabel('KEr/KE of maxKE atom')
plt.plot(x,y,'.')
fig.savefig(foldername + filename + '_ratio_KEr_KE_maxatom' + '_scale'  + '.png',bbox_inches='tight')   # save the figure to file

# %%
scale_x = 'linear'
scale_y = 'linear'

x_variable_name = 'Step'
y1_variable_name = 'c_ke_rotate'
y2_variable_name = 'v_check_value'
y3_variable_name = 'Atoms'

timestep_start = 1
timestep_end = -1

x = datapd[x_variable_name][timestep_start: timestep_end]
y1 = datapd[y1_variable_name][timestep_start: timestep_end]
y2 = datapd[y2_variable_name][timestep_start: timestep_end]
y3 = datapd[y3_variable_name][timestep_start: timestep_end]

x = x.values.astype('float64')
y1 = y1.values.astype('float64')
y2 = y2.values.astype('float64')
y3 = y3.values.astype('float64')

y = y1*y3/y2

fig = plt.figure()
plt.xscale(scale_x)
plt.yscale(scale_y)
plt.xticks(rotation=20)
plt.xlabel(x_variable_name)
plt.ylabel('KEr/KE')
plt.plot(x,y,'.')
fig.savefig(foldername + filename + '_ratio_KEr_KE' + '_scale' + '.png',bbox_inches='tight')   # save the figure to file

# %%
(+0.029760491**2+ 0.030929238**2 )**0.5/2/rp
# Out:
# 51.71334429300986

# %%
(0.025526161**2+0.02624064**2)**0.5/2/rp
# Out:
# 44.1061955479359

# %%
-8*10^-
